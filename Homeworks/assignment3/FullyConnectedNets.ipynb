# %% [markdown]
# # Fully-Connected Neural Nets
# In the previous homework you implemented a fully-connected two-layer neural network on CIFAR-10. The implementation was simple but not very modular since the loss and gradient were computed in a single monolithic function. This is manageable for a simple two-layer network, but would become impractical as we move to bigger models. Ideally we want to build networks using a more modular design so that we can implement different layer types in isolation and then snap them together into models with different architectures.
#
# In this exercise we will implement fully-connected networks using a more modular approach. For each layer we will implement a `forward` and a `backward` function. The `forward` function will receive inputs, weights, and other parameters and will return both an output and a `cache` object storing data needed for the backward pass, like this:
#
# ```python
# def layer_forward(x, w):
#   """ Receive inputs x and weights w """
#   # Do some computations ...
#   z = # ... some intermediate value
#   # Do some more computations ...
#   out = # the output
#
#   cache = (x, w, z, out) # Values we need to compute gradients
#
#   return out, cache
# ```
#
# The backward pass will receive upstream derivatives and the `cache` object, and will return gradients with respect to the inputs and weights, like this:
#
# ```python
# def layer_backward(dout, cache):
#   """
#   Receive dout (derivative of loss with respect to outputs) and cache,
#   and compute derivative with respect to inputs.
#   """
#   # Unpack cache values
#   x, w, z, out = cache
#
#   # Use values in cache to compute derivatives
#   dx = # Derivative of loss with respect to x
#   dw = # Derivative of loss with respect to w
#
#   return dx, dw
# ```
#
# After implementing a bunch of layers this way, we will be able to easily combine them to build classifiers with different architectures.
#
# In addition to implementing fully-connected networks of arbitrary depth, we will also explore different update rules for optimization, and introduce Batch/Layer Normalization as a tool to more efficiently optimize deep networks.

# %%
# # This mounts your Google Drive to the Colab VM.
# from google.colab import drive
# drive.mount('/content/drive')

# # TODO: Enter the foldername in your Drive where you have saved the unzipped
# # assignment folder, e.g. 'cs6353/assignments/assignment3/'
# FOLDERNAME = 'assignment3'
# assert FOLDERNAME is not None, "[!] Enter the foldername."

# # Now that we've mounted your Drive, this ensures that
# # the Python interpreter of the Colab VM can load
# # python files from within it.
# import sys
# sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))

# # This downloads the CIFAR-10 dataset to your Drive
# # if it doesn't already exist.
# %cd /content/drive/My\ Drive/$FOLDERNAME/cs6353/datasets/
# !bash get_datasets.sh
# %cd /content/drive/My\ Drive/$FOLDERNAME

# # Install requirements from colab_requirements.txt
# # TODO: Please change your path below to the colab_requirements.txt file
# ! python -m pip install -r /content/drive/My\ Drive/$FOLDERNAME/requirements.txt

# %%
# --------- Laptop ---------
# %cd "/home/jared/Desktop/Fall2025/CS-6353/Homeworks/assignment3/cs6353/datasets/"
# !bash get_datasets.sh
# %cd "/home/jared/Desktop/Fall2025/CS-6353/Homeworks/assignment3"
# --------- Laptop ---------

# --------- Desktop ---------
# %cd "/home/jared/CS-6353/Homeworks/assignment3/cs6353/datasets/"
# !bash get_datasets.sh
# %cd "/home/jared/CS-6353/Homeworks/assignment3/"
# --------- Desktop ---------

# Install requirements from colab_requirements.txt
# --------- Desktop ---------
! python -m pip install -r "/home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt"
# --------- Desktop ---------

# --------- Laptop ---------
# ! python -m pip install -r "/home/jared/Desktop/Fall2025/CS-6353/Homeworks/assignment3/requirements.txt"
# --------- Laptop ---------
# Out:
# /home/jared/CS-6353/Homeworks/assignment3/cs6353/datasets
# --2025-10-27 15:37:54--  https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# Resolving www.cs.toronto.edu (www.cs.toronto.edu)... 128.100.3.30
# Connecting to www.cs.toronto.edu (www.cs.toronto.edu)|128.100.3.30|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 170498071 (163M) [application/x-gzip]
# Saving to: ‘cifar-10-python.tar.gz’
#
# cifar-10-python.tar 100%[===================>] 162.60M  60.6MB/s    in 2.7s
#
# 2025-10-27 15:37:57 (60.6 MB/s) - ‘cifar-10-python.tar.gz’ saved [170498071/170498071]
#
# cifar-10-batches-py/
# cifar-10-batches-py/data_batch_4
# cifar-10-batches-py/readme.html
# cifar-10-batches-py/test_batch
# cifar-10-batches-py/data_batch_3
# cifar-10-batches-py/batches.meta
# cifar-10-batches-py/data_batch_2
# cifar-10-batches-py/data_batch_5
# cifar-10-batches-py/data_batch_1
# /home/jared/CS-6353/Homeworks/assignment3
# Requirement already satisfied: attrs in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 1)) (25.4.0)
# Requirement already satisfied: backcall in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 2)) (0.2.0)
# Requirement already satisfied: bleach in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 3)) (6.2.0)
# Requirement already satisfied: certifi in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 4)) (2025.10.5)
# Requirement already satisfied: cycler in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 5)) (0.12.1)
# Requirement already satisfied: decorator in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 6)) (5.2.1)
# Requirement already satisfied: defusedxml in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 7)) (0.7.1)
# Requirement already satisfied: entrypoints in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 8)) (0.4)
# Requirement already satisfied: future in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 9)) (1.0.0)
# Requirement already satisfied: imageio in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 10)) (2.37.0)
# Requirement already satisfied: ipykernel in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 11)) (7.0.1)
# Requirement already satisfied: ipython in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 12)) (8.37.0)
# Requirement already satisfied: ipython-genutils in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 13)) (0.2.0)
# Requirement already satisfied: ipywidgets in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 14)) (8.1.7)
# Requirement already satisfied: jedi in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 15)) (0.19.2)
# Requirement already satisfied: Jinja2 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 16)) (3.1.6)
# Requirement already satisfied: jsonschema in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 17)) (4.25.1)
# Requirement already satisfied: jupyter in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 18)) (1.1.1)
# Requirement already satisfied: jupyter-client in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 19)) (8.6.3)
# Requirement already satisfied: jupyter-console in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 20)) (6.6.3)
# Requirement already satisfied: jupyter-core in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 21)) (5.9.1)
# Requirement already satisfied: kiwisolver in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 22)) (1.4.9)
# Requirement already satisfied: MarkupSafe in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 23)) (3.0.3)
# Requirement already satisfied: matplotlib in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 24)) (3.10.7)
# Requirement already satisfied: mistune in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 25)) (3.1.4)
# Requirement already satisfied: mkl-fft in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 26)) (2.0.0)
# Requirement already satisfied: mkl-random in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 27)) (1.2.11)
# Requirement already satisfied: nbconvert in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 29)) (7.16.6)
# Requirement already satisfied: nbformat in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 30)) (5.10.4)
# Requirement already satisfied: notebook in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 31)) (7.4.7)
# Requirement already satisfied: numpy in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 32)) (2.2.6)
# Requirement already satisfied: olefile in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 33)) (0.47)
# Requirement already satisfied: pandocfilters in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 34)) (1.5.1)
# Requirement already satisfied: parso in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 35)) (0.8.5)
# Requirement already satisfied: pexpect in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 36)) (4.9.0)
# Requirement already satisfied: pickleshare in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 37)) (0.7.5)
# Requirement already satisfied: Pillow in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 38)) (12.0.0)
# Requirement already satisfied: prometheus-client in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 39)) (0.23.1)
# Requirement already satisfied: prompt-toolkit in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 40)) (3.0.52)
# Requirement already satisfied: ptyprocess in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 41)) (0.7.0)
# Requirement already satisfied: Pygments in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 42)) (2.19.2)
# Requirement already satisfied: pyparsing in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 43)) (3.2.5)
# Requirement already satisfied: pyrsistent in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 44)) (0.20.0)
# Requirement already satisfied: python-dateutil in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 45)) (2.9.0.post0)
# Requirement already satisfied: pytz in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 46)) (2025.2)
# Requirement already satisfied: pyzmq in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 47)) (27.1.0)
# Requirement already satisfied: qtconsole in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 48)) (5.7.0)
# Requirement already satisfied: scipy in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 49)) (1.15.3)
# Requirement already satisfied: Send2Trash in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 50)) (1.8.3)
# Requirement already satisfied: six in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 51)) (1.17.0)
# Requirement already satisfied: terminado in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 52)) (0.18.1)
# Requirement already satisfied: testpath in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 53)) (0.6.0)
# Requirement already satisfied: tornado in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 54)) (6.5.1)
# Requirement already satisfied: traitlets in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 55)) (5.14.3)
# Requirement already satisfied: wcwidth in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 56)) (0.2.14)
# Requirement already satisfied: webencodings in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 57)) (0.5.1)
# Requirement already satisfied: widgetsnbextension in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from -r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 58)) (4.0.14)
# Requirement already satisfied: comm>=0.1.1 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from ipykernel->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 11)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from ipykernel->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 11)) (1.8.16)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from ipykernel->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 11)) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from ipykernel->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 11)) (1.6.0)
# Requirement already satisfied: packaging>=22 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from ipykernel->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 11)) (25.0)
# Requirement already satisfied: psutil>=5.7 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from ipykernel->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 11)) (7.0.0)
# Requirement already satisfied: exceptiongroup in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from ipython->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 12)) (1.3.0)
# Requirement already satisfied: stack_data in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from ipython->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 12)) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from ipython->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 12)) (4.15.0)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from ipywidgets->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 14)) (3.0.15)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from jsonschema->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 17)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from jsonschema->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 17)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from jsonschema->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 17)) (0.28.0)
# Requirement already satisfied: jupyterlab in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from jupyter->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 18)) (4.4.10)
# Requirement already satisfied: platformdirs>=2.5 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from jupyter-core->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 21)) (4.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from matplotlib->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 24)) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from matplotlib->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 24)) (4.60.1)
# Requirement already satisfied: mkl-service in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from mkl-fft->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 26)) (2.5.2)
# Requirement already satisfied: mkl in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from mkl-fft->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 26)) (2025.3.0)
# Requirement already satisfied: beautifulsoup4 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from nbconvert->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 29)) (4.14.2)
# Requirement already satisfied: jupyterlab-pygments in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from nbconvert->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 29)) (0.3.0)
# Requirement already satisfied: nbclient>=0.5.0 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from nbconvert->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 29)) (0.10.2)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from nbformat->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 30)) (2.21.2)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from notebook->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 31)) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from notebook->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 31)) (2.28.0)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from notebook->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 31)) (0.2.4)
# Requirement already satisfied: anyio>=3.1.0 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 31)) (4.11.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 31)) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 31)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 31)) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 31)) (7.7.0)
# Requirement already satisfied: websocket-client>=1.7 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 31)) (1.9.0)
# Requirement already satisfied: async-lru>=1.0.0 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from jupyterlab->jupyter->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 18)) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from jupyterlab->jupyter->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 18)) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from jupyterlab->jupyter->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 18)) (2.3.0)
# Requirement already satisfied: setuptools>=41.1.0 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from jupyterlab->jupyter->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 18)) (80.9.0)
# Requirement already satisfied: tomli>=1.2.2 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from jupyterlab->jupyter->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 18)) (2.3.0)
# Requirement already satisfied: httpcore==1.* in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 18)) (1.0.9)
# Requirement already satisfied: idna in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 18)) (3.11)
# Requirement already satisfied: h11>=0.16 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 18)) (0.16.0)
# Requirement already satisfied: babel>=2.10 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->notebook->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 31)) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->notebook->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 31)) (0.12.1)
# Requirement already satisfied: requests>=2.31 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->notebook->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 31)) (2.32.5)
# Requirement already satisfied: ipython_pygments_lexers in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from qtconsole->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 48)) (1.1.1)
# Requirement already satisfied: qtpy>=2.4.0 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from qtconsole->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 48)) (2.4.3)
# Requirement already satisfied: sniffio>=1.1 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 31)) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 31)) (25.1.0)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from bleach[css]!=5.0.0->nbconvert->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 29)) (1.4.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 31)) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 31)) (6.0.3)
# Requirement already satisfied: rfc3339-validator in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 31)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 31)) (0.1.1)
# Requirement already satisfied: fqdn in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 31)) (1.5.1)
# Requirement already satisfied: isoduration in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 31)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 31)) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 31)) (1.1.0)
# Requirement already satisfied: uri-template in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 31)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 31)) (24.11.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 31)) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 31)) (2.5.0)
# Requirement already satisfied: lark>=1.2.2 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 31)) (1.3.0)
# Requirement already satisfied: cffi>=1.0.1 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 31)) (2.0.0)
# Requirement already satisfied: pycparser in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 31)) (2.23)
# Requirement already satisfied: soupsieve>1.2 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from beautifulsoup4->nbconvert->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 29)) (2.8)
# Requirement already satisfied: arrow>=0.15.0 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 31)) (1.4.0)
# Requirement already satisfied: tzdata in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 31)) (2025.2)
# Requirement already satisfied: onemkl-license==2025.3.0 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from mkl->mkl-fft->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 26)) (2025.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from mkl->mkl-fft->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 26)) (2025.3.0)
# Requirement already satisfied: tbb==2022.* in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from mkl->mkl-fft->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 26)) (2022.3.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2025.3.0 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from intel-openmp<2026,>=2024->mkl->mkl-fft->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 26)) (2025.3.0)
# Requirement already satisfied: umf==1.0.* in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from intel-cmplr-lib-ur==2025.3.0->intel-openmp<2026,>=2024->mkl->mkl-fft->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 26)) (1.0.2)
# Requirement already satisfied: tcmlib==1.* in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from tbb==2022.*->mkl->mkl-fft->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 26)) (1.4.1)
# Requirement already satisfied: executing>=1.2.0 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from stack_data->ipython->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 12)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from stack_data->ipython->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 12)) (3.0.0)
# Requirement already satisfied: pure_eval in /home/jared/anaconda3/envs/CS6353/lib/python3.10/site-packages (from stack_data->ipython->-r /home/jared/CS-6353/Homeworks/assignment3/requirements_no_ver.txt (line 12)) (0.2.3)

# %%
# As usual, a bit of setup
from __future__ import print_function
import time
import numpy as np
import matplotlib.pyplot as plt
from cs6353.classifiers.fc_net import *
from cs6353.data_utils import get_CIFAR10_data
from cs6353.gradient_check import eval_numerical_gradient, eval_numerical_gradient_array
from cs6353.solver import Solver

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
  """ returns relative error """
  return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Load the (preprocessed) CIFAR10 data.
data = get_CIFAR10_data()
for k, v in list(data.items()):
  print(('%s: ' % k, v.shape))
# Out:
# ('X_train: ', (49000, 3, 32, 32))
# ('y_train: ', (49000,))
# ('X_val: ', (1000, 3, 32, 32))
# ('y_val: ', (1000,))
# ('X_test: ', (1000, 3, 32, 32))
# ('y_test: ', (1000,))

# %% [markdown]
# # Affine layer: foward
# Open the file `cs6353/layers.py` and implement the `affine_forward` function.
#
# Once you are done you can test your implementaion by running the following:

# %%
# Test the affine_forward function

num_inputs = 2
input_shape = (4, 5, 6)
output_dim = 3

input_size = num_inputs * np.prod(input_shape)
weight_size = output_dim * np.prod(input_shape)

x = np.linspace(-0.1, 0.5, num=input_size).reshape(num_inputs, *input_shape)
w = np.linspace(-0.2, 0.3, num=weight_size).reshape(np.prod(input_shape), output_dim)
b = np.linspace(-0.3, 0.1, num=output_dim)

out, _ = affine_forward(x, w, b)
correct_out = np.array([[ 1.49834967,  1.70660132,  1.91485297],
                        [ 3.25553199,  3.5141327,   3.77273342]])

# Compare your output with ours. The error should be around e-9 or less.
print('Testing affine_forward function:')
print('difference: ', rel_error(out, correct_out))
# Out:
# orig_shape: (2, 4, 5, 6)
# x shape: (2, 120)
# w shape: (120, 3)
# b shape: (3,)
# Testing affine_forward function:
# difference:  9.769849468192957e-10

# %% [markdown]
# # Affine layer: backward
# Now implement the `affine_backward` function and test your implementation using numeric gradient checking.

# %%
# Test the affine_backward function
np.random.seed(231)
x = np.random.randn(10, 2, 3)
w = np.random.randn(6, 5)
b = np.random.randn(5)
dout = np.random.randn(10, 5)

dx_num = eval_numerical_gradient_array(lambda x: affine_forward(x, w, b)[0], x, dout)
dw_num = eval_numerical_gradient_array(lambda w: affine_forward(x, w, b)[0], w, dout)
db_num = eval_numerical_gradient_array(lambda b: affine_forward(x, w, b)[0], b, dout)

_, cache = affine_forward(x, w, b)
dx, dw, db = affine_backward(dout, cache)

# The error should be around e-10 or less
print('Testing affine_backward function:')
print('dx error: ', rel_error(dx_num, dx))
print('dw error: ', rel_error(dw_num, dw))
print('db error: ', rel_error(db_num, db))
# Out:
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# orig_shape: (10, 2, 3)
# x shape: (10, 6)
# w shape: (6, 5)
# b shape: (5,)
# Testing affine_backward function:
# dx error:  5.399100368651805e-11
# dw error:  9.904211865398145e-11
# db error:  2.4122867568119087e-11

# %% [markdown]
# # ReLU activation: forward
# Implement the forward pass for the ReLU activation function in the `relu_forward` function and test your implementation using the following:

# %%
# Test the relu_forward function

x = np.linspace(-0.5, 0.5, num=12).reshape(3, 4)

out, _ = relu_forward(x)
correct_out = np.array([[ 0.,          0.,          0.,          0.,        ],
                        [ 0.,          0.,          0.04545455,  0.13636364,],
                        [ 0.22727273,  0.31818182,  0.40909091,  0.5,       ]])

# Compare your output with ours. The error should be on the order of e-8
print('Testing relu_forward function:')
print('difference: ', rel_error(out, correct_out))
# Out:
# Testing relu_forward function:
# difference:  4.999999798022158e-08

# %% [markdown]
# # ReLU activation: backward
# Now implement the backward pass for the ReLU activation function in the `relu_backward` function and test your implementation using numeric gradient checking:

# %%
np.random.seed(231)
x = np.random.randn(10, 10)
dout = np.random.randn(*x.shape)

dx_num = eval_numerical_gradient_array(lambda x: relu_forward(x)[0], x, dout)

_, cache = relu_forward(x)
dx = relu_backward(dout, cache)

# The error should be on the order of e-12
print('Testing relu_backward function:')
print('dx error: ', rel_error(dx_num, dx))
# Out:
# Testing relu_backward function:
# dx error:  3.2756349136310288e-12

# %% [markdown]
# ## Inline Question 1:
#
# We've only asked you to implement ReLU, but there are a number of different activation functions that one could use in neural networks, each with its pros and cons. In particular, an issue commonly seen with activation functions is getting zero (or close to zero) gradient flow during backpropagation. Which of the following activation functions have this problem? If you consider these functions in the one dimensional case, what types of input would lead to this behaviour?
# 1. Sigmoid
# 2. ReLU
# 3. Leaky ReLU

# %% [markdown]
# ## Answer:
# Sigmoid has this problem. For a single example this problem can be seen if we set the input of sigmoid high. In my testing I set the input value to 100. This causes the sigmoid function to be 1. When you do the derivative sig(x)(1-sig(x)) you get a value of 0 which isn't an actionable gradient. This happens because sigmoid squashes large values between 0 and 1 and very large values will get squashed very close to either 0 or 1 depending on if they are very large or very small

# %% [markdown]
# # "Sandwich" layers
# There are some common patterns of layers that are frequently used in neural nets. For example, affine layers are frequently followed by a ReLU nonlinearity. To make these common patterns easy, we define several convenience layers in the file `cs6353/layer_utils.py`.
#
# For now take a look at the `affine_relu_forward` and `affine_relu_backward` functions, and run the following to numerically gradient check the backward pass:

# %%
from cs6353.layer_utils import affine_relu_forward, affine_relu_backward
np.random.seed(231)
x = np.random.randn(2, 3, 4)
w = np.random.randn(12, 10)
b = np.random.randn(10)
dout = np.random.randn(2, 10)

out, cache = affine_relu_forward(x, w, b)
dx, dw, db = affine_relu_backward(dout, cache)

dx_num = eval_numerical_gradient_array(lambda x: affine_relu_forward(x, w, b)[0], x, dout)
dw_num = eval_numerical_gradient_array(lambda w: affine_relu_forward(x, w, b)[0], w, dout)
db_num = eval_numerical_gradient_array(lambda b: affine_relu_forward(x, w, b)[0], b, dout)

# Relative error should be around e-10 or less
print('Testing affine_relu_forward and affine_relu_backward:')
print('dx error: ', rel_error(dx_num, dx))
print('dw error: ', rel_error(dw_num, dw))
print('db error: ', rel_error(db_num, db))
# Out:
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# orig_shape: (2, 3, 4)
# x shape: (2, 12)
# w shape: (12, 10)
# b shape: (10,)
# Testing affine_relu_forward and affine_relu_backward:
# dx error:  2.299579177309368e-11
# dw error:  8.162011105764925e-11
# db error:  7.826724021458994e-12

# %% [markdown]
# # Loss layers: Softmax and SVM
# You implemented these loss functions in the last assignment, so we'll give them to you for free here. You should still make sure you understand how they work by looking at the implementations in `cs6353/layers.py`.
#
# You can make sure that the implementations are correct by running the following:

# %%
np.random.seed(231)
num_classes, num_inputs = 10, 50
x = 0.001 * np.random.randn(num_inputs, num_classes)
y = np.random.randint(num_classes, size=num_inputs)

dx_num = eval_numerical_gradient(lambda x: svm_loss(x, y)[0], x, verbose=False)
loss, dx = svm_loss(x, y)

# Test svm_loss function. Loss should be around 9 and dx error should be around the order of e-9
print('Testing svm_loss:')
print('loss: ', loss)
print('dx error: ', rel_error(dx_num, dx))

dx_num = eval_numerical_gradient(lambda x: softmax_loss(x, y)[0], x, verbose=False)
loss, dx = softmax_loss(x, y)

# Test softmax_loss function. Loss should be close to 2.3 and dx error should be around e-8
print('\nTesting softmax_loss:')
print('loss: ', loss)
print('dx error: ', rel_error(dx_num, dx))
# Out:
# Testing svm_loss:
# loss:  8.999602749096233
# dx error:  1.4021566006651672e-09
#
# Testing softmax_loss:
# loss:  2.302545844500738
# dx error:  9.384673161989355e-09

# %% [markdown]
# # Two-layer network
# In the previous assignment you implemented a two-layer neural network in a single monolithic class. Now that you have implemented modular versions of the necessary layers, you will reimplement the two layer network using these modular implementations.
#
# Open the file `cs6353/classifiers/fc_net.py` and complete the implementation of the `TwoLayerNet` class. This class will serve as a model for the other networks you will implement in this assignment, so read through it to make sure you understand the API. You can run the cell below to test your implementation.

# %%
np.random.seed(231)
N, D, H, C = 3, 5, 50, 7
X = np.random.randn(N, D)
y = np.random.randint(C, size=N)

std = 1e-3
model = TwoLayerNet(input_dim=D, hidden_dim=H, num_classes=C, weight_scale=std)

print('Testing initialization ... ')
W1_std = abs(model.params['W1'].std() - std)
b1 = model.params['b1']
W2_std = abs(model.params['W2'].std() - std)
b2 = model.params['b2']
assert W1_std < std / 10, 'First layer weights do not seem right'
assert np.all(b1 == 0), 'First layer biases do not seem right'
assert W2_std < std / 10, 'Second layer weights do not seem right'
assert np.all(b2 == 0), 'Second layer biases do not seem right'

print('Testing test-time forward pass ... ')
model.params['W1'] = np.linspace(-0.7, 0.3, num=D*H).reshape(D, H)
model.params['b1'] = np.linspace(-0.1, 0.9, num=H)
model.params['W2'] = np.linspace(-0.3, 0.4, num=H*C).reshape(H, C)
model.params['b2'] = np.linspace(-0.9, 0.1, num=C)
X = np.linspace(-5.5, 4.5, num=N*D).reshape(D, N).T
scores = model.loss(X)
correct_scores = np.asarray(
  [[11.53165108,  12.2917344,   13.05181771,  13.81190102,  14.57198434, 15.33206765,  16.09215096],
   [12.05769098,  12.74614105,  13.43459113,  14.1230412,   14.81149128, 15.49994135,  16.18839143],
   [12.58373087,  13.20054771,  13.81736455,  14.43418138,  15.05099822, 15.66781506,  16.2846319 ]])
scores_diff = np.abs(scores - correct_scores).sum()
assert scores_diff < 1e-6, 'Problem with test-time forward pass'

print('Testing training loss (no regularization)')
y = np.asarray([0, 5, 1])
loss, grads = model.loss(X, y)
correct_loss = 3.4702243556
assert abs(loss - correct_loss) < 1e-10, 'Problem with training-time loss'

model.reg = 1.0
loss, grads = model.loss(X, y)
correct_loss = 26.5948426952
assert abs(loss - correct_loss) < 1e-10, 'Problem with regularization loss'

# Errors should be around e-7 or less
for reg in [0.0, 0.7]:
  print('Running numeric gradient check with reg = ', reg)
  model.reg = reg
  loss, grads = model.loss(X, y)

  for name in sorted(grads):
    f = lambda _: model.loss(X, y)[0]
    grad_num = eval_numerical_gradient(f, model.params[name], verbose=False)
    print('%s relative error: %.2e' % (name, rel_error(grad_num, grads[name])))
# Out:
# Testing initialization ...
# Testing test-time forward pass ...
# Testing training loss (no regularization)
# Running numeric gradient check with reg =  0.0
# W1 relative error: 1.83e-08
# W2 relative error: 3.12e-10
# b1 relative error: 9.83e-09
# b2 relative error: 4.33e-10
# Running numeric gradient check with reg =  0.7
# W1 relative error: 2.53e-07
# W2 relative error: 2.85e-08
# b1 relative error: 1.56e-08
# b2 relative error: 7.76e-10

# %% [markdown]
# # Solver
# In the previous assignment, the logic for training models was coupled to the models themselves. Following a more modular design, for this assignment we have split the logic for training models into a separate class.
#
# Open the file `cs6353/solver.py` and read through it to familiarize yourself with the API. After doing so, use a `Solver` instance to train a `TwoLayerNet` that achieves at least `50%` accuracy on the validation set.

# %%
model = TwoLayerNet()
solver = None

##############################################################################
# TODO: Use a Solver instance to train a TwoLayerNet that achieves at least  #
# 50% accuracy on the validation set.                                        #
##############################################################################
data = {
  'X_train': data['X_train'],
  'y_train': data['y_train'],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

solver = Solver(model, data,
                update_rule='sgd',
                optim_config={
                  'learning_rate': 1e-3,
                },
                lr_decay=0.95,
                num_epochs=10, batch_size=100,
                print_every=100)

solver.train()
##############################################################################
#                             END OF YOUR CODE                               #
##############################################################################
# Out:
# (Iteration 1 / 4900) loss: 2.301830
# (Epoch 0 / 10) train acc: 0.131000; val_acc: 0.131000
# (Iteration 101 / 4900) loss: 1.802899
# (Iteration 201 / 4900) loss: 1.768696
# (Iteration 301 / 4900) loss: 1.782735
# (Iteration 401 / 4900) loss: 1.532687
# (Epoch 1 / 10) train acc: 0.468000; val_acc: 0.444000
# (Iteration 501 / 4900) loss: 1.563991
# (Iteration 601 / 4900) loss: 1.465715
# (Iteration 701 / 4900) loss: 1.511521
# (Iteration 801 / 4900) loss: 1.642600
# (Iteration 901 / 4900) loss: 1.563162
# (Epoch 2 / 10) train acc: 0.511000; val_acc: 0.450000
# (Iteration 1001 / 4900) loss: 1.264173
# (Iteration 1101 / 4900) loss: 1.173215
# (Iteration 1201 / 4900) loss: 1.444569
# (Iteration 1301 / 4900) loss: 1.463054
# (Iteration 1401 / 4900) loss: 1.477484
# (Epoch 3 / 10) train acc: 0.508000; val_acc: 0.468000
# (Iteration 1501 / 4900) loss: 1.449015
# (Iteration 1601 / 4900) loss: 1.423241
# (Iteration 1701 / 4900) loss: 1.495351
# (Iteration 1801 / 4900) loss: 1.470207
# (Iteration 1901 / 4900) loss: 1.312690
# (Epoch 4 / 10) train acc: 0.537000; val_acc: 0.487000
# (Iteration 2001 / 4900) loss: 1.149732
# (Iteration 2101 / 4900) loss: 1.506606
# (Iteration 2201 / 4900) loss: 1.280980
# (Iteration 2301 / 4900) loss: 1.195192
# (Iteration 2401 / 4900) loss: 1.348681
# (Epoch 5 / 10) train acc: 0.527000; val_acc: 0.505000
# (Iteration 2501 / 4900) loss: 1.193943
# (Iteration 2601 / 4900) loss: 1.057687
# (Iteration 2701 / 4900) loss: 1.136165
# (Iteration 2801 / 4900) loss: 1.247242
# (Iteration 2901 / 4900) loss: 1.353230
# (Epoch 6 / 10) train acc: 0.576000; val_acc: 0.508000
# (Iteration 3001 / 4900) loss: 1.188247
# (Iteration 3101 / 4900) loss: 1.001560
# (Iteration 3201 / 4900) loss: 1.086713
# (Iteration 3301 / 4900) loss: 1.186212
# (Iteration 3401 / 4900) loss: 1.216888
# (Epoch 7 / 10) train acc: 0.583000; val_acc: 0.502000
# (Iteration 3501 / 4900) loss: 1.140258
# (Iteration 3601 / 4900) loss: 1.119206
# (Iteration 3701 / 4900) loss: 1.213349
# (Iteration 3801 / 4900) loss: 1.014232
# (Iteration 3901 / 4900) loss: 1.174274
# (Epoch 8 / 10) train acc: 0.560000; val_acc: 0.521000
# (Iteration 4001 / 4900) loss: 1.278147
# (Iteration 4101 / 4900) loss: 1.274661
# (Iteration 4201 / 4900) loss: 1.382458
# (Iteration 4301 / 4900) loss: 1.407067
# (Iteration 4401 / 4900) loss: 1.140060
# (Epoch 9 / 10) train acc: 0.568000; val_acc: 0.495000
# (Iteration 4501 / 4900) loss: 1.047418
# (Iteration 4601 / 4900) loss: 1.007733
# (Iteration 4701 / 4900) loss: 1.380312
# (Iteration 4801 / 4900) loss: 1.191733
# (Epoch 10 / 10) train acc: 0.622000; val_acc: 0.517000

# %%
# Run this cell to visualize training loss and train / val accuracy

plt.subplot(2, 1, 1)
plt.title('Training loss')
plt.plot(solver.loss_history, 'o')
plt.xlabel('Iteration')

plt.subplot(2, 1, 2)
plt.title('Accuracy')
plt.plot(solver.train_acc_history, '-o', label='train')
plt.plot(solver.val_acc_history, '-o', label='val')
plt.plot([0.5] * len(solver.val_acc_history), 'k--')
plt.xlabel('Epoch')
plt.legend(loc='lower right')
plt.gcf().set_size_inches(15, 12)
plt.show()

# %% [markdown]
# # Multilayer network
# Next you will implement a fully-connected network with an arbitrary number of hidden layers.
#
# Read through the `FullyConnectedNet` class in the file `cs6353/classifiers/fc_net.py`.
#
# Implement the initialization, the forward pass, and the backward pass. For the moment don't worry about implementing batch/layer normalization; we will add those features soon.

# %% [markdown]
# ## Initial loss and gradient check

# %% [markdown]
# As a sanity check, run the following to check the initial loss and to gradient check the network both with and without regularization. Do the initial losses seem reasonable?
#
# For gradient checking, you should expect to see errors around 1e-7 or less.

# %%
np.random.seed(231)
N, D, H1, H2, C = 2, 15, 20, 30, 10
X = np.random.randn(N, D)
y = np.random.randint(C, size=(N,))

for reg in [0, 3.14]:
  print('Running check with reg = ', reg)
  model = FullyConnectedNet([H1, H2], input_dim=D, num_classes=C,
                            reg=reg, weight_scale=5e-2, dtype=np.float64)

  loss, grads = model.loss(X, y)
  print('Initial loss: ', loss)

  # Most of the errors should be on the order of e-7 or smaller.
  # NOTE: It is fine however to see an error for W2 on the order of e-5
  # for the check when reg = 0.0
  for name in sorted(grads):
    f = lambda _: model.loss(X, y)[0]
    grad_num = eval_numerical_gradient(f, model.params[name], verbose=False, h=1e-5)
    print('%s relative error: %.2e' % (name, rel_error(grad_num, grads[name])))
# Out:
# Running check with reg =  0
# Initial loss:  2.3004790897684924
# W1 relative error: 1.48e-07
# W2 relative error: 2.21e-05
# W3 relative error: 3.53e-07
# b1 relative error: 5.38e-09
# b2 relative error: 2.09e-09
# b3 relative error: 5.80e-11
# Running check with reg =  3.14
# Initial loss:  7.052114776533016
# W1 relative error: 6.86e-09
# W2 relative error: 3.52e-08
# W3 relative error: 1.32e-08
# b1 relative error: 1.48e-08
# b2 relative error: 1.72e-09
# b3 relative error: 1.80e-10

# %% [markdown]
# As another sanity check, make sure you can overfit a small dataset of 50 images. First we will try a three-layer network with 100 units in each hidden layer. In the following cell, tweak the learning rate and initialization scale to overfit and achieve 100% training accuracy within 20 epochs.

# %%
# TODO: Use a three-layer Net to overfit 50 training examples by
# tweaking just the learning rate and initialization scale.

num_train = 50
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

# weight_scale = 1e-2
# learning_rate = 5e-3

weight_scale = 1e-2
learning_rate = 5e-3
model = FullyConnectedNet([100, 100],
              weight_scale=weight_scale, dtype=np.float64)
solver = Solver(model, small_data,
                print_every=10, num_epochs=20, batch_size=25,
                update_rule='sgd',
                optim_config={
                  'learning_rate': learning_rate,
                }
         )
solver.train()

plt.plot(solver.loss_history, 'o')
plt.title('Training loss history')
plt.xlabel('Iteration')
plt.ylabel('Training loss')
plt.show()
# Out:
# (Iteration 1 / 40) loss: 2.305551
# (Epoch 0 / 20) train acc: 0.180000; val_acc: 0.120000
# (Epoch 1 / 20) train acc: 0.260000; val_acc: 0.112000
# (Epoch 2 / 20) train acc: 0.460000; val_acc: 0.152000
# (Epoch 3 / 20) train acc: 0.400000; val_acc: 0.150000
# (Epoch 4 / 20) train acc: 0.460000; val_acc: 0.167000
# (Epoch 5 / 20) train acc: 0.560000; val_acc: 0.156000
# (Iteration 11 / 40) loss: 1.640325
# (Epoch 6 / 20) train acc: 0.520000; val_acc: 0.167000
# (Epoch 7 / 20) train acc: 0.520000; val_acc: 0.169000
# (Epoch 8 / 20) train acc: 0.680000; val_acc: 0.175000
# (Epoch 9 / 20) train acc: 0.680000; val_acc: 0.204000
# (Epoch 10 / 20) train acc: 0.800000; val_acc: 0.182000
# (Iteration 21 / 40) loss: 1.184994
# (Epoch 11 / 20) train acc: 0.740000; val_acc: 0.191000
# (Epoch 12 / 20) train acc: 0.840000; val_acc: 0.177000
# (Epoch 13 / 20) train acc: 0.900000; val_acc: 0.184000
# (Epoch 14 / 20) train acc: 0.860000; val_acc: 0.191000
# (Epoch 15 / 20) train acc: 0.940000; val_acc: 0.182000
# (Iteration 31 / 40) loss: 0.350507
# (Epoch 16 / 20) train acc: 0.920000; val_acc: 0.191000
# (Epoch 17 / 20) train acc: 0.980000; val_acc: 0.176000
# (Epoch 18 / 20) train acc: 1.000000; val_acc: 0.176000
# (Epoch 19 / 20) train acc: 0.980000; val_acc: 0.197000
# (Epoch 20 / 20) train acc: 1.000000; val_acc: 0.189000

# %% [markdown]
# Now try to use a five-layer network with 100 units on each layer to overfit 50 training examples. Again you will have to adjust the learning rate and weight initialization, but you should be able to achieve 100% training accuracy within 20 epochs.

# %%
# TODO: Use a five-layer Net to overfit 50 training examples by
# tweaking just the learning rate and initialization scale.

num_train = 50
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

learning_rate = 2e-3
weight_scale = 1e-1
model = FullyConnectedNet([100, 100, 100, 100],
                weight_scale=weight_scale, dtype=np.float64)
solver = Solver(model, small_data,
                print_every=10, num_epochs=20, batch_size=25,
                update_rule='sgd',
                optim_config={
                  'learning_rate': learning_rate,
                }
         )
solver.train()

plt.plot(solver.loss_history, 'o')
plt.title('Training loss history')
plt.xlabel('Iteration')
plt.ylabel('Training loss')
plt.show()
# Out:
# (Iteration 1 / 40) loss: 186.502272
# (Epoch 0 / 20) train acc: 0.180000; val_acc: 0.116000
# (Epoch 1 / 20) train acc: 0.160000; val_acc: 0.078000
# (Epoch 2 / 20) train acc: 0.200000; val_acc: 0.098000
# (Epoch 3 / 20) train acc: 0.300000; val_acc: 0.124000
# (Epoch 4 / 20) train acc: 0.560000; val_acc: 0.091000
# (Epoch 5 / 20) train acc: 0.600000; val_acc: 0.099000
# (Iteration 11 / 40) loss: 1.939877
# (Epoch 6 / 20) train acc: 0.840000; val_acc: 0.101000
# (Epoch 7 / 20) train acc: 0.860000; val_acc: 0.086000
# (Epoch 8 / 20) train acc: 0.900000; val_acc: 0.089000
# (Epoch 9 / 20) train acc: 0.960000; val_acc: 0.089000
# (Epoch 10 / 20) train acc: 1.000000; val_acc: 0.086000
# (Iteration 21 / 40) loss: 0.005438
# (Epoch 11 / 20) train acc: 1.000000; val_acc: 0.086000
# (Epoch 12 / 20) train acc: 1.000000; val_acc: 0.084000
# (Epoch 13 / 20) train acc: 1.000000; val_acc: 0.084000
# (Epoch 14 / 20) train acc: 1.000000; val_acc: 0.084000
# (Epoch 15 / 20) train acc: 1.000000; val_acc: 0.084000
# (Iteration 31 / 40) loss: 0.002339
# (Epoch 16 / 20) train acc: 1.000000; val_acc: 0.085000
# (Epoch 17 / 20) train acc: 1.000000; val_acc: 0.085000
# (Epoch 18 / 20) train acc: 1.000000; val_acc: 0.085000
# (Epoch 19 / 20) train acc: 1.000000; val_acc: 0.085000
# (Epoch 20 / 20) train acc: 1.000000; val_acc: 0.086000

# %% [markdown]
# ## Inline Question 2:
# Did you notice anything about the comparative difficulty of training the three-layer net vs training the five layer net? In particular, based on your experience, which network seemed more sensitive to the initialization scale? Why do you think that is the case?
#
# - Response: It was much easier to train the five layer network to get 100% accuracy. This makes a lot of sense from what we've seen in class. The more layers your network has the more expressible it is. This can be a double edged sword as seen in the example above. I think this is the same reason why the initiailzation scale had a bigger effect on the smaller network. Because we have less resources it is harder for them to learn the data exactly.

# %% [markdown]
# ## Answer:

# %% [markdown]
# # Update rules
# So far we have used vanilla stochastic gradient descent (SGD) as our update rule. More sophisticated update rules can make it easier to train deep networks. We will implement a few of the most commonly used update rules and compare them to vanilla SGD.

# %% [markdown]
# # SGD+Momentum
# Stochastic gradient descent with momentum is a widely used update rule that tends to make deep networks converge faster than vanilla stochastic gradient descent.
#
# Open the file `cs6353/optim.py` and read the documentation at the top of the file to make sure you understand the API. Implement the SGD+momentum update rule in the function `sgd_momentum` and run the following to check your implementation. You should see errors less than e-8.

# %%
from cs6353.optim import sgd_momentum

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
v = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)

config = {'learning_rate': 1e-3, 'velocity': v}
next_w, _ = sgd_momentum(w, dw, config=config)

expected_next_w = np.asarray([
  [ 0.1406,      0.20738947,  0.27417895,  0.34096842,  0.40775789],
  [ 0.47454737,  0.54133684,  0.60812632,  0.67491579,  0.74170526],
  [ 0.80849474,  0.87528421,  0.94207368,  1.00886316,  1.07565263],
  [ 1.14244211,  1.20923158,  1.27602105,  1.34281053,  1.4096    ]])
expected_velocity = np.asarray([
  [ 0.5406,      0.55475789,  0.56891579, 0.58307368,  0.59723158],
  [ 0.61138947,  0.62554737,  0.63970526,  0.65386316,  0.66802105],
  [ 0.68217895,  0.69633684,  0.71049474,  0.72465263,  0.73881053],
  [ 0.75296842,  0.76712632,  0.78128421,  0.79544211,  0.8096    ]])

# Should see relative errors around e-8 or less
print('next_w error: ', rel_error(next_w, expected_next_w))
print('velocity error: ', rel_error(expected_velocity, config['velocity']))
# Out:
# next_w error:  8.882347033505819e-09
# velocity error:  4.269287743278663e-09

# %% [markdown]
# Once you have done so, run the following to train a six-layer network with both SGD and SGD+momentum. You should see the SGD+momentum update rule converge faster.

# %%
num_train = 4000
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

solvers = {}

for update_rule in ['sgd', 'sgd_momentum']:
  print('running with ', update_rule)
  model = FullyConnectedNet([100, 100, 100, 100, 100], weight_scale=5e-2)

  solver = Solver(model, small_data,
                  num_epochs=5, batch_size=100,
                  update_rule=update_rule,
                  optim_config={
                    'learning_rate': 1e-2,
                  },
                  verbose=True)
  solvers[update_rule] = solver
  solver.train()
  print()

plt.subplot(3, 1, 1)
plt.title('Training loss')
plt.xlabel('Iteration')

plt.subplot(3, 1, 2)
plt.title('Training accuracy')
plt.xlabel('Epoch')

plt.subplot(3, 1, 3)
plt.title('Validation accuracy')
plt.xlabel('Epoch')

for update_rule, solver in list(solvers.items()):
  plt.subplot(3, 1, 1)
  plt.plot(solver.loss_history, 'o', label=update_rule)

  plt.subplot(3, 1, 2)
  plt.plot(solver.train_acc_history, '-o', label=update_rule)

  plt.subplot(3, 1, 3)
  plt.plot(solver.val_acc_history, '-o', label=update_rule)

for i in [1, 2, 3]:
  plt.subplot(3, 1, i)
  plt.legend(loc='upper center', ncol=4)
plt.gcf().set_size_inches(15, 15)
plt.show()
# Out:
# running with  sgd
# (Iteration 1 / 200) loss: 2.704739
# (Epoch 0 / 5) train acc: 0.128000; val_acc: 0.096000
# (Iteration 11 / 200) loss: 2.230597
# (Iteration 21 / 200) loss: 2.207152
# (Iteration 31 / 200) loss: 2.100736
# (Epoch 1 / 5) train acc: 0.253000; val_acc: 0.241000
# (Iteration 41 / 200) loss: 1.983646
# (Iteration 51 / 200) loss: 1.957013
# (Iteration 61 / 200) loss: 2.039531
# (Iteration 71 / 200) loss: 1.939943
# (Epoch 2 / 5) train acc: 0.325000; val_acc: 0.288000
# (Iteration 81 / 200) loss: 2.011945
# (Iteration 91 / 200) loss: 1.802832
# (Iteration 101 / 200) loss: 1.923910
# (Iteration 111 / 200) loss: 1.678418
# (Epoch 3 / 5) train acc: 0.371000; val_acc: 0.315000
# (Iteration 121 / 200) loss: 1.659691
# (Iteration 131 / 200) loss: 1.719881
# (Iteration 141 / 200) loss: 1.705133
# (Iteration 151 / 200) loss: 1.808572
# (Epoch 4 / 5) train acc: 0.430000; val_acc: 0.317000
# (Iteration 161 / 200) loss: 1.691332
# (Iteration 171 / 200) loss: 1.736750
# (Iteration 181 / 200) loss: 1.541743
# (Iteration 191 / 200) loss: 1.717727
# (Epoch 5 / 5) train acc: 0.433000; val_acc: 0.331000
#
# running with  sgd_momentum
# (Iteration 1 / 200) loss: 2.841345
# (Epoch 0 / 5) train acc: 0.119000; val_acc: 0.107000
# (Iteration 11 / 200) loss: 2.112935
# (Iteration 21 / 200) loss: 2.094369
# (Iteration 31 / 200) loss: 1.930321
# (Epoch 1 / 5) train acc: 0.274000; val_acc: 0.260000
# (Iteration 41 / 200) loss: 1.973267
# (Iteration 51 / 200) loss: 1.835496
# (Iteration 61 / 200) loss: 1.698632
# (Iteration 71 / 200) loss: 1.798790
# (Epoch 2 / 5) train acc: 0.382000; val_acc: 0.350000
# (Iteration 81 / 200) loss: 1.748700
# (Iteration 91 / 200) loss: 1.556700
# (Iteration 101 / 200) loss: 1.605721
# (Iteration 111 / 200) loss: 1.615264
# (Epoch 3 / 5) train acc: 0.459000; val_acc: 0.328000
# (Iteration 121 / 200) loss: 1.465242
# (Iteration 131 / 200) loss: 1.480918
# (Iteration 141 / 200) loss: 1.514882
# (Iteration 151 / 200) loss: 1.617001
# (Epoch 4 / 5) train acc: 0.476000; val_acc: 0.348000
# (Iteration 161 / 200) loss: 1.511035
# (Iteration 171 / 200) loss: 1.485877
# (Iteration 181 / 200) loss: 1.467156
# (Iteration 191 / 200) loss: 1.298826
# (Epoch 5 / 5) train acc: 0.493000; val_acc: 0.354000

# %% [markdown]
# # Train a good model!
# Train the best fully-connected model that you can on CIFAR-10, storing your best model in the `best_model` variable. We require you to get at least 50% accuracy on the validation set using a fully-connected net.
#
# If you are careful it should be possible to get accuracies above 55%, but we don't require it for this part and won't assign extra credit for doing so. Later in the assignment we will ask you to train the best convolutional network that you can on CIFAR-10, and we would prefer that you spend your effort working on convolutional nets rather than fully-connected nets.
#
# You might find it useful to complete the `BatchNormalization.ipynb` notebook before completing this part, since those techniques can help you train powerful models.

# %%
best_model = None
################################################################################
# TODO: Train the best FullyConnectedNet that you can on CIFAR-10. You might   #
# find batch/layer normalization useful. Store your best model in  #
# the best_model variable.                                                     #
################################################################################

################################################################################
#                              END OF YOUR CODE                                #
################################################################################

# %% [markdown]
# # Test your model!
# Run your best model on the validation and test sets. You should achieve above 50% accuracy on the validation set.

# %%
y_test_pred = np.argmax(best_model.loss(data['X_test']), axis=1)
y_val_pred = np.argmax(best_model.loss(data['X_val']), axis=1)
print('Validation set accuracy: ', (y_val_pred == data['y_val']).mean())
print('Test set accuracy: ', (y_test_pred == data['y_test']).mean())
